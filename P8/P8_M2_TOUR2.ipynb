# %% [markdown]
# ![BAN%20PROJET%208.png](attachment:BAN%20PROJET%208.png)

# %% [markdown]
# ### Mission 2 : Création d'un dataframe pour lister les informations de chaque candidat
#
# - Création d'une table avec l'ensemble des données

# %% [markdown]
# ### Sommaire // Mission 2 ✉️
#
# * [1.Importation des librairies et parametres df](#1)
# * [2.Importation des fichiers CSV](#2)
# * [3.Préparation des tables pour Tableau](#3)

# %% [markdown]
# ## 1.Importation des librairies et parametres df <a class="anchor" id="1"></a>

# %%
#j'importe les librairies qui vont me servir plus tard
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

#Je definis le nombre de lignes max affichées sur None
pd.set_option("max_rows", None) 
pd.set_option("display.precision",7)

# %% [markdown]
# ## 2.Importation des fichiers CSV <a class="anchor" id="2"></a>

# %%
#Je charge tous les fichiers csv
data_p8_1tour = pd.read_csv("D:/DA_P8/CSV/election-presidentielle-2017-resultats-par-bureaux-de-vote-tour-1.csv",sep=';',encoding='utf-8-sig',decimal=".")

#J'affiche une phrase si l'import est reussi
print("Fichiers chargés avec succes!")
# Out:
# Fichiers chargés avec succes!

# %% [markdown]
# ## 3.Création d'une table avec l'ensemble des données <a class="anchor" id="3"></a>

# %%
# Création d'une table avec les données du sondage
Fiche2 = pd.DataFrame({'Prénom' :  ['Emmanuel','Marine'],
                        'Nom' :  ['MACRON','LE PEN'],
                        'Sexe' :  ['M','F'],
                        'Date_de_naissance' :  ['21/12/1977','05/08/1968',],
                        'Age' :  ['44','53'],
                        'Lieu_de_naissance' :  ['Amiens','Neuilly-sur-Seine'],
                        'Nationalité' :  ['Française','Française'],
                        'Parti_politique' :  ['EM/LREM','FN/RN'],
                        'Profession' :  ['Haut fonctionnaire/Haut fonctionnaire','Avocate'],
                        'Diplomé_de' :  ['Université Paris-Nanterre/IEP de Paris/ENA','Université Panthéon-Assas']})
Fiche2
# Out:
#      Prénom     Nom Sexe Date_de_naissance Age  Lieu_de_naissance Nationalité  \
# 0  Emmanuel  MACRON    M        21/12/1977  44             Amiens   Française
# 1    Marine  LE PEN    F        05/08/1968  53  Neuilly-sur-Seine   Française
#
#   Parti_politique                             Profession  \
# 0         EM/LREM  Haut fonctionnaire/Haut fonctionnaire
# 1           FN/RN                                Avocate
#
#                                    Diplomé_de
# 0  Université Paris-Nanterre/IEP de Paris/ENA
# 1                   Université Panthéon-Assas

# %%
#J'exporte ma table en CSV pour la suite
Fiche2.to_csv("D:/DA_P8/CSV/Fiche2.csv",sep=',', index=False,encoding='utf-8-sig',decimal=".")
