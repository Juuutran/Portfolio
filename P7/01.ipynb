# %% [markdown]
# ![BAN%20P7.png](attachment:BAN%20P7.png)

# %% [markdown]
# ### Mission 1 : Résumez les données utilisées
#
# - année(s) des données utilisées ;
# - nombre de pays présents ;
# - population couverte par l'analyse (en termes de pourcentage de la population mondiale).
#
# Les données de la World Income Distribution présentent pour chaque pays les quantiles de la distribution des revenus de leur population respective.
#
# <font color='royalblue'> De quel type de quantiles s'agit-il (quartiles, déciles, etc.) ? </font>
#
# <font color='royalblue'> Échantillonner une population en utilisant des quantiles est-il selon vous une bonne méthode ? Pourquoi ? </font>

# %% [markdown]
# ### Sommaire // Mission 1 🔮
#
# * [1.Importation des librairies et parametres df](#1)
# * [2.Importation des fichiers CSV](#2)
# * [3.Nettoyage des différentes tables](#3)
#     * [3.1.data_projet7](#3.1)
#         * [3.1.1.Valeurs manquantes, nulles et NA](#3.1.1)
#             * [3.1.1.1.Corrections des valeurs manquantes, nulles et NA](#3.1.1.1)
#         * [3.1.2.Doublons](#3.1.2)
#         * [3.1.3.Outliers, valeurs abberantes et atypiques](#3.1.3)
#     * [3.2.Population et indice de gini](#3.2)
#         * [3.2.1.Valeurs manquantes, nulles et NA](#3.2.1)
#             * [3.2.1.1.Corrections des valeurs manquantes, nulles et NA](#3.2.1.1)
#         * [3.2.2.Doublons](#3.2.2)
#         * [3.2.3.Outliers, valeurs abberantes et atypiques](#3.2.3)
#         * [3.2.4.Ajout d'une colonne ISO3](#3.2.4)
#         * [3.2.5.Jointure de Population et data_projet7](#3.2.5)
#     * [3.3.Proportion de la population étudiée vs 2008](#3.3)

# %% [markdown]
# ## 1.Importation des librairies et parametres df <a class="anchor" id="1"></a>

# %%
#j'importe les librairies qui vont me servir plus tard
import numpy as np
import pandas as pd

#Je definis le nombre de lignes max affichées sur None
pd.set_option("max_rows", None) 
pd.set_option("display.precision",7)

# %% [markdown]
# ## 2.Importation des fichiers CSV <a class="anchor" id="2"></a>

# %%
#Je charge tous les fichiers csv
data_projet7 = pd.read_csv("C:/Users/33643/Desktop/P7/CSV/data-projet7.csv",decimal=",")
Population = pd.read_csv("C:/Users/33643/Desktop/P7/CSV/WIID_31MAY2021_0.csv",decimal=".")
country_code_en = pd.read_csv("C:/Users/33643/Desktop/P7/CSV/country-code-en.csv",decimal=",")

#J'affiche une phrase si l'import est reussi
print("Fichiers chargés avec succes!")
# Out:
# Fichiers chargés avec succes!
# C:\Users\33643\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## 3.Nettoyage des différentes tables <a class="anchor" id="3"></a>

# %%
country_code_en.head()
# Out:
#              Pays ISO2 ISO3  ISOON
# 0     Afghanistan   AF  AFG      4
# 1   Aland Islands   AX  ALA    248
# 2         Albania   AL  ALB      8
# 3         Algeria   DZ  DZA     12
# 4  American Samoa   AS  ASM     16

# %%
len(country_code_en['ISO3'].unique())
# Out:
# 247

# %% [markdown]
# ## 3.1.data_projet7 <a class="anchor" id="3.1"></a>

# %%
data_projet7.head(3)
# Out:
#   country  year_survey  quantile  nb_quantiles      income  gdpppp
# 0     ALB         2008         1           100   728.89795  7297.0
# 1     ALB         2008         2           100   916.66235  7297.0
# 2     ALB         2008         3           100  1010.91600  7297.0

# %%
data_projet7.shape
# Out:
# (11599, 6)

# %%
data_projet7.dtypes
# Out:
# country          object
# year_survey       int64
# quantile          int64
# nb_quantiles      int64
# income          float64
# gdpppp          float64
# dtype: object

# %%
print(data_projet7.isnull().any())
print(data_projet7.isnull().sum())
# Out:
# country         False
# year_survey     False
# quantile        False
# nb_quantiles    False
# income          False
# gdpppp           True
# dtype: bool
# country           0
# year_survey       0
# quantile          0
# nb_quantiles      0
# income            0
# gdpppp          200
# dtype: int64

# %%
# Restriction sur year_survey avec valeurs uniques
data_projet7.groupby(by=['year_survey']).nunique()
# Out:
#              country  quantile  nb_quantiles  income  gdpppp
# year_survey
# 2004               1       100             1     100       1
# 2006               5       100             1     500       5
# 2007              15       100             1    1500      15
# 2008              76       100             1    7598      75
# 2009              12       100             1    1200      11
# 2010               6       100             1     600       6
# 2011               1       100             1     100       1

# %% [markdown]
# ### Je remarque que les pays sont répartis selon plusieurs années, et majoritairement pour l'année 2008. J'utiliserai donc la population de l'année 2008 pour calculer mon pourcentage de population représenté.

# %% [markdown]
# ### <font color='red'> Les quantiles utilisés dans la table data_projet7 sont des centiles </font>

# %% [markdown]
# #### <font color='red'> Outre la spécification de la position d'un ensemble de données, les quantiles sont utiles à d'autres égards. Supposons que nous ayons un échantillon aléatoire simple d'une population et que la distribution de la population soit inconnue. Pour aider à déterminer si un modèle, comme une distribution normale ou une distribution de Weibull convient bien à la population à partir de laquelle nous avons échantillonné, nous pouvons examiner les quantiles de nos données et du modèle.
#
# #### <font color='red'> En faisant correspondre les quantiles de nos échantillons de données aux quantiles d'une distribution de probabilité particulière, le résultat est une collection de données appariées. Nous représentons ces données dans un nuage de points, connu sous le nom de graphique quantile-quantile ou graphique q-q. Si le nuage de points résultant est à peu près linéaire, alors le modèle est un bon ajustement pour nos données. </font>

# %% [markdown]
# ### <font color='red'> Les années couverte par l'étude sont 2004, 2006, 2007, 2008, 2009, 2010 et 2011 </font>

# %%
len(data_projet7['country'].unique())
# Out:
# 116

# %% [markdown]
# ### <font color='red'> Le nombre de pays couverts par l'étude est de 116 </font>

# %%
# J'ajoute le nom des pays à la table en faisant une jointure avec la table country_code_en
data_projet7 = pd.merge(data_projet7, country_code_en, left_on= 'country', right_on= 'ISO3', how= 'left')
data_projet7 = data_projet7.drop(columns =['ISO2','ISOON','ISO3'])
data_projet7 = data_projet7.rename(columns ={'country':'ISO3'})

data_projet7.head(3)
# Out:
#   ISO3  year_survey  quantile  nb_quantiles      income  gdpppp     Pays
# 0  ALB         2008         1           100   728.89795  7297.0  Albania
# 1  ALB         2008         2           100   916.66235  7297.0  Albania
# 2  ALB         2008         3           100  1010.91600  7297.0  Albania

# %% [markdown]
# ## 3.1.1.Valeurs manquantes, nulles et NA <a class="anchor" id="3.1.1"></a>

# %%
print(data_projet7.isnull().any())
print(data_projet7.isnull().sum())
# Out:
# ISO3            False
# year_survey     False
# quantile        False
# nb_quantiles    False
# income          False
# gdpppp           True
# Pays             True
# dtype: bool
# ISO3              0
# year_survey       0
# quantile          0
# nb_quantiles      0
# income            0
# gdpppp          200
# Pays            100
# dtype: int64

# %%
# Je vérifie que certaine variables ne présentent de données
data_projet7_uniq = data_projet7.groupby(by='ISO3').nunique()
data_projet7_uniq.head(3)
# Out:
#       year_survey  quantile  nb_quantiles  income  gdpppp  Pays
# ISO3
# ALB             1       100             1     100       1     1
# ARG             1       100             1     100       1     1
# ARM             1       100             1     100       1     1

# %%
# Vérification pour la variable bdpppp
data_projet7_uniq.loc[data_projet7_uniq['gdpppp'] < 1]
# Out:
#       year_survey  quantile  nb_quantiles  income  gdpppp  Pays
# ISO3
# PSE             1       100             1     100       0     1
# XKX             1       100             1     100       0     0

# %%
# Vérification pour la variable income
data_projet7_uniq.loc[data_projet7_uniq['income'] < 100]
# Out:
#       year_survey  quantile  nb_quantiles  income  gdpppp  Pays
# ISO3
# LTU             1        99             1      99       1     1

# %% [markdown]
# ### Les pays PSE et XKX ne présentent pas de gdpppp, XKX ne présente pas de nom de pays

# %%
# Vérification pour la variable quantile
data_projet7_uniq.loc[data_projet7_uniq['quantile'] < 100]
# Out:
#       year_survey  quantile  nb_quantiles  income  gdpppp  Pays
# ISO3
# LTU             1        99             1      99       1     1

# %% [markdown]
# ### Le pays LTU ne présente pas 100 quantiles mais 99, il manque une ligne

# %% [markdown]
# ## 3.1.1.1.Corrections des valeurs manquantes, nulles et NA <a class="anchor" id="3.1.1.1"></a>

# %%
# J'affecte le nom du pays et du GDP PPP pour XKX
data_projet7.loc[data_projet7['ISO3'] == 'XKX', 'Pays'] = 'Kosovo'
data_projet7.loc[data_projet7['ISO3'] == 'XKX', 'gdpppp'] = 7530.632

data_projet7.loc[data_projet7['ISO3'] == 'XKX'].head(1)
# Out:
#      ISO3  year_survey  quantile  nb_quantiles    income    gdpppp    Pays
# 5800  XKX         2008         1           100  437.8937  7530.632  Kosovo

# %%
# J'affecte le GDP PPP pour PSE
data_projet7.loc[data_projet7['ISO3'] == 'PSE', 'gdpppp'] = 3612.14

data_projet7.loc[data_projet7['ISO3'] == 'PSE'].head(1)
# Out:
#       ISO3  year_survey  quantile  nb_quantiles    income   gdpppp  \
# 11199  PSE         2009         1           100  195.2899  3612.14
#
#                                  Pays
# 11199  Palestinian Territory Occupied

# %%
# Je recherche le quantile manquant pour LTU
data_projet7_LTU = data_projet7.loc[data_projet7['ISO3'] == 'LTU']
data_projet7_LTU = data_projet7_LTU.reset_index(drop=True)
data_projet7_LTU
# Out:
#    ISO3  year_survey  quantile  nb_quantiles      income   gdpppp       Pays
# 0   LTU         2008         1           100    566.3453  17571.0  Lithuania
# 1   LTU         2008         2           100   1147.0587  17571.0  Lithuania
# 2   LTU         2008         3           100   1490.8408  17571.0  Lithuania
# 3   LTU         2008         4           100   1746.5715  17571.0  Lithuania
# 4   LTU         2008         5           100   1842.9542  17571.0  Lithuania
# 5   LTU         2008         6           100   1925.8641  17571.0  Lithuania
# 6   LTU         2008         7           100   2048.3857  17571.0  Lithuania
# 7   LTU         2008         8           100   2173.7112  17571.0  Lithuania
# 8   LTU         2008         9           100   2302.0857  17571.0  Lithuania
# 9   LTU         2008        10           100   2361.6480  17571.0  Lithuania
# 10  LTU         2008        11           100   2452.7578  17571.0  Lithuania
# 11  LTU         2008        12           100   2602.3857  17571.0  Lithuania
# 12  LTU         2008        13           100   2732.9660  17571.0  Lithuania
# 13  LTU         2008        14           100   2849.0960  17571.0  Lithuania
# 14  LTU         2008        15           100   3010.8962  17571.0  Lithuania
# 15  LTU         2008        16           100   3121.6091  17571.0  Lithuania
# 16  LTU         2008        17           100   3174.2260  17571.0  Lithuania
# 17  LTU         2008        18           100   3264.4023  17571.0  Lithuania
# 18  LTU         2008        19           100   3338.4468  17571.0  Lithuania
# 19  LTU         2008        20           100   3405.9260  17571.0  Lithuania
# 20  LTU         2008        21           100   3516.2354  17571.0  Lithuania
# 21  LTU         2008        22           100   3588.2507  17571.0  Lithuania
# 22  LTU         2008        23           100   3673.9355  17571.0  Lithuania
# 23  LTU         2008        24           100   3781.4660  17571.0  Lithuania
# 24  LTU         2008        25           100   3864.0430  17571.0  Lithuania
# 25  LTU         2008        26           100   3930.2112  17571.0  Lithuania
# 26  LTU         2008        27           100   3990.3855  17571.0  Lithuania
# 27  LTU         2008        28           100   4048.9220  17571.0  Lithuania
# 28  LTU         2008        29           100   4109.7764  17571.0  Lithuania
# 29  LTU         2008        30           100   4190.6610  17571.0  Lithuania
# 30  LTU         2008        31           100   4254.9070  17571.0  Lithuania
# 31  LTU         2008        32           100   4317.0664  17571.0  Lithuania
# 32  LTU         2008        33           100   4360.1040  17571.0  Lithuania
# 33  LTU         2008        34           100   4425.0396  17571.0  Lithuania
# 34  LTU         2008        35           100   4503.2373  17571.0  Lithuania
# 35  LTU         2008        36           100   4591.1064  17571.0  Lithuania
# 36  LTU         2008        37           100   4701.1330  17571.0  Lithuania
# 37  LTU         2008        38           100   4756.4336  17571.0  Lithuania
# 38  LTU         2008        39           100   4802.3680  17571.0  Lithuania
# 39  LTU         2008        40           100   4868.4507  17571.0  Lithuania
# 40  LTU         2008        42           100   4895.8306  17571.0  Lithuania
# 41  LTU         2008        43           100   4950.6380  17571.0  Lithuania
# 42  LTU         2008        44           100   5006.7860  17571.0  Lithuania
# 43  LTU         2008        45           100   5028.5444  17571.0  Lithuania
# 44  LTU         2008        46           100   5088.5090  17571.0  Lithuania
# 45  LTU         2008        47           100   5165.5580  17571.0  Lithuania
# 46  LTU         2008        48           100   5239.3403  17571.0  Lithuania
# 47  LTU         2008        49           100   5327.5730  17571.0  Lithuania
# 48  LTU         2008        50           100   5444.4650  17571.0  Lithuania
# 49  LTU         2008        51           100   5504.8830  17571.0  Lithuania
# 50  LTU         2008        52           100   5603.5140  17571.0  Lithuania
# 51  LTU         2008        53           100   5696.4630  17571.0  Lithuania
# 52  LTU         2008        54           100   5781.1665  17571.0  Lithuania
# 53  LTU         2008        55           100   5901.3584  17571.0  Lithuania
# 54  LTU         2008        56           100   5991.1370  17571.0  Lithuania
# 55  LTU         2008        57           100   6047.4106  17571.0  Lithuania
# 56  LTU         2008        58           100   6109.0680  17571.0  Lithuania
# 57  LTU         2008        59           100   6174.0190  17571.0  Lithuania
# 58  LTU         2008        60           100   6288.1055  17571.0  Lithuania
# 59  LTU         2008        61           100   6400.7720  17571.0  Lithuania
# 60  LTU         2008        62           100   6482.5703  17571.0  Lithuania
# 61  LTU         2008        63           100   6586.7974  17571.0  Lithuania
# 62  LTU         2008        64           100   6698.0460  17571.0  Lithuania
# 63  LTU         2008        65           100   6807.5670  17571.0  Lithuania
# 64  LTU         2008        66           100   6909.9780  17571.0  Lithuania
# 65  LTU         2008        67           100   7021.7725  17571.0  Lithuania
# 66  LTU         2008        68           100   7121.1353  17571.0  Lithuania
# 67  LTU         2008        69           100   7233.9300  17571.0  Lithuania
# 68  LTU         2008        70           100   7377.1690  17571.0  Lithuania
# 69  LTU         2008        71           100   7461.7430  17571.0  Lithuania
# 70  LTU         2008        72           100   7578.0720  17571.0  Lithuania
# 71  LTU         2008        73           100   7735.5150  17571.0  Lithuania
# 72  LTU         2008        74           100   7871.6920  17571.0  Lithuania
# 73  LTU         2008        75           100   7931.4917  17571.0  Lithuania
# 74  LTU         2008        76           100   8025.3325  17571.0  Lithuania
# 75  LTU         2008        77           100   8147.3590  17571.0  Lithuania
# 76  LTU         2008        78           100   8251.6010  17571.0  Lithuania
# 77  LTU         2008        79           100   8415.2560  17571.0  Lithuania
# 78  LTU         2008        80           100   8631.9840  17571.0  Lithuania
# 79  LTU         2008        81           100   8809.2280  17571.0  Lithuania
# 80  LTU         2008        82           100   9067.0950  17571.0  Lithuania
# 81  LTU         2008        83           100   9252.7540  17571.0  Lithuania
# 82  LTU         2008        84           100   9533.1310  17571.0  Lithuania
# 83  LTU         2008        85           100   9827.6780  17571.0  Lithuania
# 84  LTU         2008        86           100  10014.9820  17571.0  Lithuania
# 85  LTU         2008        87           100  10198.4920  17571.0  Lithuania
# 86  LTU         2008        88           100  10471.2680  17571.0  Lithuania
# 87  LTU         2008        89           100  10830.9150  17571.0  Lithuania
# 88  LTU         2008        90           100  11192.9790  17571.0  Lithuania
# 89  LTU         2008        91           100  11553.6070  17571.0  Lithuania
# 90  LTU         2008        92           100  12073.0230  17571.0  Lithuania
# 91  LTU         2008        93           100  12520.6920  17571.0  Lithuania
# 92  LTU         2008        94           100  13091.2540  17571.0  Lithuania
# 93  LTU         2008        95           100  13752.7340  17571.0  Lithuania
# 94  LTU         2008        96           100  14597.0360  17571.0  Lithuania
# 95  LTU         2008        97           100  15659.0080  17571.0  Lithuania
# 96  LTU         2008        98           100  17883.8770  17571.0  Lithuania
# 97  LTU         2008        99           100  22551.1700  17571.0  Lithuania
# 98  LTU         2008       100           100  38836.5300  17571.0  Lithuania

# %% [markdown]
# ### Je remarque qu'il manque le quantile 41

# %%
# Calcul du quantile manquant par la moyenne des quantiles autour
income_40 = 4868.4507
income_42 = 4895.8306
income_40_41 = (income_40+income_42)/2
income_40_41
# Out:
# 4882.14065

# %%
# Création de la ligne manquante
LTU_41 = pd.DataFrame({'ISO3' :  ['LTU'],
                        'year_survey' : [2008],
                        'quantile' : [41],
                        'nb_quantiles' : [100],
                        'income' : [income_40_41],
                        'gdpppp'  :  [17571],
                        'Pays' : ['Lithuania']})
LTU_41
# Out:
#   ISO3  year_survey  quantile  nb_quantiles      income  gdpppp       Pays
# 0  LTU         2008        41           100  4882.14065   17571  Lithuania

# %%
# Concaténation avec la talbe data_projet7
data_projet7 = pd.concat([data_projet7, LTU_41], ignore_index=True)
data_projet7.tail(3)
# Out:
#       ISO3  year_survey  quantile  nb_quantiles      income       gdpppp  \
# 11597  COD         2008        99           100  1286.60290    303.19305
# 11598  COD         2008       100           100  2243.12260    303.19305
# 11599  LTU         2008        41           100  4882.14065  17571.00000
#
#                                    Pays
# 11597  Congo Democratic Republic of the
# 11598  Congo Democratic Republic of the
# 11599                         Lithuania

# %%
print(data_projet7.isnull().any())
print(data_projet7.isnull().sum())
# Out:
# ISO3            False
# year_survey     False
# quantile        False
# nb_quantiles    False
# income          False
# gdpppp          False
# Pays            False
# dtype: bool
# ISO3            0
# year_survey     0
# quantile        0
# nb_quantiles    0
# income          0
# gdpppp          0
# Pays            0
# dtype: int64

# %% [markdown]
# ## 3.1.2.Doublons <a class="anchor" id="3.1.2"></a>

# %%
print(data_projet7.duplicated().any())
print(data_projet7.duplicated().sum())
# Out:
# False
# 0

# %% [markdown]
# ## 3.1.3.Outliers, valeurs abberantes et atypiques <a class="anchor" id="3.1.3"></a>

# %%
# Je regarde les extremes pour la colonne income et gdpppp
data_projet7.groupby('ISO3').mean().sort_values('gdpppp').tail()
# Out:
#       year_survey  quantile  nb_quantiles         income     gdpppp
# ISO3
# IRL        2008.0      50.5         100.0  17710.7358380    39268.0
# USA        2008.0      50.5         100.0  25503.5816610    43261.0
# NOR        2008.0      50.5         100.0  22483.3750200    49070.0
# LUX        2008.0      50.5         100.0  25217.5626810    73127.0
# FJI        2008.0      50.5         100.0   2098.7308823  4300332.0

# %%
data_projet7.groupby('ISO3').mean().sort_values('income').tail()
# Out:
#       year_survey  quantile  nb_quantiles         income   gdpppp
# ISO3
# NOR        2008.0      50.5         100.0  22483.3750200  49070.0
# CAN        2008.0      50.5         100.0  23739.6405181  35895.0
# LUX        2008.0      50.5         100.0  25217.5626810  73127.0
# USA        2008.0      50.5         100.0  25503.5816610  43261.0
# ISL        2008.0      50.5         100.0  26888.5115180  36527.0

# %% [markdown]
# ### Le pays FJI affiche une moyenne gdpppp bien trop haute, la valeur est à modifier.

# %% [markdown]
# ### RAS pour l'income

# %%
# j'affectate une valeur de GDP PPP plus cohérente
data_projet7.loc[data_projet7['ISO3'] == 'FJI', 'gdpppp'] = 7384.086
data_projet7.loc[data_projet7['ISO3'] == 'FJI'].head()
# Out:
#      ISO3  year_survey  quantile  nb_quantiles     income    gdpppp  Pays
# 3200  FJI         2008         1           100  308.17334  7384.086  Fiji
# 3201  FJI         2008         2           100  384.33230  7384.086  Fiji
# 3202  FJI         2008         3           100  436.59265  7384.086  Fiji
# 3203  FJI         2008         4           100  486.81436  7384.086  Fiji
# 3204  FJI         2008         5           100  520.19720  7384.086  Fiji

# %%
data_projet7 = data_projet7.rename(columns ={'year_survey':'Year'})
data_projet7 = data_projet7.rename(columns ={'Pays':'Country'})

# %%
len(data_projet7['Country'].unique())
# Out:
# 116

# %% [markdown]
# ## 3.2.Population <a class="anchor" id="3.2"></a>
#
# *World Income Inequality Database - WIID - 31 May 2021*

# %%
Population.head(3)
# Out:
#    id      country   c3  c2  year  gini  ge0  ge1  ge2  a025  ...  \
# 0   1  Afghanistan  AFG  AF  2008  29.0  NaN  NaN  NaN   NaN  ...
# 1   2  Afghanistan  AFG  AF  2012  33.0  NaN  NaN  NaN   NaN  ...
# 2   3  Afghanistan  AFG  AF  2017  31.0  NaN  NaN  NaN   NaN  ...
#
#       population  revision  quality  quality_score  \
# 0    27,722,282   New 2019     High             12
# 1    31,161,378   New 2019     High             12
# 2    36,296,108   New 2019     High             12
#
#                            source  \
# 0  National statistical authority
# 1  National statistical authority
# 2  National statistical authority
#
#                                      source_detailed  source_comments  \
# 0  European Union and the Central Statistics Orga...              NaN
# 1  European Union and the Central Statistics Orga...              NaN
# 2  European Union and the Central Statistics Orga...              NaN
#
#                            survey  \
# 0  Living Conditions Survey (LCS)
# 1  Living Conditions Survey (LCS)
# 2  Living Conditions Survey (LCS)
#
#                                                 link  wiidcompanion
# 0  https://cso-of-afghanistan.shinyapps.io/ALCS_D...            Yes
# 1  https://cso-of-afghanistan.shinyapps.io/ALCS_D...            Yes
# 2  https://eeas.europa.eu/regions/asia/44072/resu...            Yes
#
# [3 rows x 67 columns]

# %%
Population.shape
# Out:
# (20675, 67)

# %%
# Je supprime les virugules de la colonne population pour poivoir pleinement utiliser celle-ci
Population['population'] = Population['population'].str.replace(',', '')

# %%
Population['population'].dtypes
# Out:
# dtype('O')

# %%
Population['population'] = Population['population'].apply(pd.to_numeric,errors = 'coerce')
Population['population'].dtypes
# Out:
# dtype('float64')

# %%
#Je nettoie ma table Indice_gini
Population = Population.drop(columns =['id','ge0','ge1','ge2','a025','a050','a075','a1','palma','ratio_top20bottom20','bottom40','q1','q2','q3','q4','q5','d1','d2','d3','d4','d5','d6','d7','d8','d9','d10'])
Population = Population.drop(columns =['bottom5','top5','resource','resource_detailed','scale','scale_detailed','sharing_unit','reference_unit','areacovr','areacovr_detailed','popcovr','popcovr_detailed','region_un','region_un_sub','region_wb','eu','oecd','incomegroup','mean','median','currency','reference_period','exchangerate','mean_usd','median_usd','revision'])
Population = Population.drop(columns =['quality','quality_score','source','source_detailed','source_comments','survey','link','wiidcompanion'])
Population = Population.drop(columns =['c2','gdp'])
Population = Population.rename(columns ={'country':'Country'})
Population = Population.rename(columns ={'c3':'ISO3'})
Population = Population.rename(columns ={'year':'Year'})
Population = Population.rename(columns ={'population':'Population'})

Population.head(3)
# Out:
#        Country ISO3  Year  gini  Population
# 0  Afghanistan  AFG  2008  29.0  27722282.0
# 1  Afghanistan  AFG  2012  33.0  31161378.0
# 2  Afghanistan  AFG  2017  31.0  36296108.0

# %%
Population['Year'].unique()
# Out:
# array([2008, 2012, 2017, 1996, 2002, 2005, 2014, 2015, 2016, 1988, 1995,
#        2001, 2003, 2009, 2019, 1953, 1959, 1961, 1963, 1965, 1969, 1970,
#        1972, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983,
#        1985, 1986, 1987, 1989, 1990, 1991, 1992, 1993, 1994, 1997, 1998,
#        1999, 2000, 2004, 2006, 2007, 2010, 2011, 2013, 2018, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1954, 1955,
#        1956, 1957, 1958, 1960, 1962, 1964, 1966, 1967, 1968, 1971, 1973,
#        1984, 1939, 1936, 1890, 1900, 1910, 1920, 1930, 1940, 1914, 1921,
#        1927, 1938, 2020, 1935, 1867], dtype=int64)

# %%
Population['Year'].dtypes
# Out:
# dtype('int64')

# %%
# Restriction des années ciblées précedemment (2004, 2006, 2007, 2008, 2009, 2010 et 2011)

Population = Population.loc[Population['Year'].isin([2004,2006,2007,2008,2009,2010,2011])]
Population.head()
# Out:
#         Country ISO3  Year   gini  Population
# 0   Afghanistan  AFG  2008  29.00  27722282.0
# 6       Albania  ALB  2008  29.98   3002683.0
# 21       Angola  AGO  2009  55.00  22514276.0
# 22       Angola  AGO  2009  43.00  22514276.0
# 23       Angola  AGO  2009  50.00  22514276.0

# %% [markdown]
# ## 3.2.1.Valeurs manquantes, nulles et NA <a class="anchor" id="3.2.1"></a>

# %%
print(Population.isnull().any())
print(Population.isnull().sum())
# Out:
# Country       False
# ISO3          False
# Year          False
# gini           True
# Population    False
# dtype: bool
# Country        0
# ISO3           0
# Year           0
# gini          27
# Population     0
# dtype: int64

# %%
Population[Population['gini'].isnull()]
# Out:
#          Country ISO3  Year  gini   Population
# 257      Armenia  ARM  2007   NaN    2932615.0
# 260      Armenia  ARM  2008   NaN    2907615.0
# 263      Armenia  ARM  2009   NaN    2888094.0
# 266      Armenia  ARM  2010   NaN    2877314.0
# 269      Armenia  ARM  2011   NaN    2876536.0
# 2045      Brunei  BRN  2011   NaN     393687.0
# 2296    Cambodia  KHM  2009   NaN   14093605.0
# 2298    Cambodia  KHM  2010   NaN   14312205.0
# 2300    Cambodia  KHM  2011   NaN   14541421.0
# 5975        Fiji  FJI  2009   NaN     853636.0
# 10374      Japan  JPN  2004   NaN  128204176.0
# 10386      Japan  JPN  2009   NaN  128555192.0
# 11939  Mauritius  MUS  2007   NaN    1233890.0
# 12428    Myanmar  MMR  2010   NaN   50600828.0
# 12436    Namibia  NAM  2010   NaN    2118877.0
# 13405       Oman  OMN  2011   NaN    3251102.0
# 13527   Pakistan  PAK  2011   NaN  183340176.0
# 13528   Pakistan  PAK  2011   NaN  183340176.0
# 15615  Singapore  SGP  2008   NaN    4775810.0
# 17895   Thailand  THA  2004   NaN   64995304.0
# 17897   Thailand  THA  2006   NaN   65812540.0
# 17899   Thailand  THA  2007   NaN   66182064.0
# 17903   Thailand  THA  2009   NaN   66866836.0
# 17907   Thailand  THA  2011   NaN   67518384.0
# 19968    Vietnam  VNM  2010   NaN   87967656.0
# 19970    Vietnam  VNM  2010   NaN   87967656.0
# 19972    Vietnam  VNM  2010   NaN   87967656.0

# %% [markdown]
# ### J'ai repéré 27 NaN dans la colonne gini

# %%
# Je vérifie si certaine variables ne présentent aucune données
Population_uniq = Population.groupby(by='ISO3').nunique()
Population_uniq.head()
# Out:
#       Country  Year  gini  Population
# ISO3
# AFG         1     1     1           1
# AGO         1     1     6           1
# ALB         1     1     1           1
# ARE         1     1     1           1
# ARG         1     7    34           7

# %% [markdown]
# ### RAS

# %%
# Vérification pour la variable gini
Population_uniq.loc[Population_uniq['gini'] < 1]
# Out:
#       Country  Year  gini  Population
# ISO3
# BRN         1     1     0           1
# MMR         1     1     0           1

# %%
# Je regarde de quelle année il s'agit pour les pays ERI et NRU
Population.loc[(Population['ISO3'] == "BRN")] #2011
Population.loc[(Population['ISO3'] == "MMR")] #2010
# Out:
#        Country ISO3  Year  gini  Population
# 12428  Myanmar  MMR  2010   NaN  50600828.0

# %% [markdown]
# ## J'ai repéré 2 pays sans indice de gini, toutes années confondues

# %% [markdown]
# ## 3.2.1.1.Corrections des valeurs manquantes, nulles et NA <a class="anchor" id="3.2.1.1"></a>

# %%
# Je remplace les NaN de la colonne gini pour leur affecter une nouvelle valeur
Population['gini'] = Population['gini'].fillna(0)

# %%
Population.loc[(Population['Country'] == "Armenia") & (Population['Year'] == 2007), 'gini'] = 31.2
Population.loc[(Population['Country'] == "Armenia") & (Population['Year'] == 2008), 'gini'] = 29.2
Population.loc[(Population['Country'] == "Armenia") & (Population['Year'] == 2009), 'gini'] = 28.0
Population.loc[(Population['Country'] == "Armenia") & (Population['Year'] == 2010), 'gini'] = 30.0
Population.loc[(Population['Country'] == "Armenia") & (Population['Year'] == 2011), 'gini'] = 29.4
Population.loc[(Population['Country'] == "Brunei") & (Population['Year'] == 2011), 'gini'] = 56.4 #1981
Population.loc[(Population['Country'] == "Cambodia") & (Population['Year'] == 2009), 'gini'] = 34.65
Population.loc[(Population['Country'] == "Cambodia") & (Population['Year'] == 2010), 'gini'] = 33.44
Population.loc[(Population['Country'] == "Cambodia") & (Population['Year'] == 2011), 'gini'] = 31.7
Population.loc[(Population['Country'] == "Fiji") & (Population['Year'] == 2009), 'gini'] = 40.38
Population.loc[(Population['Country'] == "Japan") & (Population['Year'] == 2004), 'gini'] = 44.3 #2003
Population.loc[(Population['Country'] == "Japan") & (Population['Year'] == 2009), 'gini'] = 39.46
Population.loc[(Population['Country'] == "Mauritius") & (Population['Year'] == 2007), 'gini'] = 35.65
Population.loc[(Population['Country'] == "Myanmar") & (Population['Year'] == 2010), 'gini'] = 38.07 #2015
Population.loc[(Population['Country'] == "Namibia") & (Population['Year'] == 2010), 'gini'] = 60.97
Population.loc[(Population['Country'] == "Oman") & (Population['Year'] == 2011), 'gini'] = 30.7
Population.loc[(Population['Country'] == "Pakistan") & (Population['Year'] == 2011), 'gini'] = 30.2
Population.loc[(Population['Country'] == "Singapore") & (Population['Year'] == 2008), 'gini'] = 47.4
Population.loc[(Population['Country'] == "Thailand") & (Population['Year'] == 2004), 'gini'] = 42.54
Population.loc[(Population['Country'] == "Thailand") & (Population['Year'] == 2006), 'gini'] = 41.82
Population.loc[(Population['Country'] == "Thailand") & (Population['Year'] == 2007), 'gini'] = 39.76
Population.loc[(Population['Country'] == "Thailand") & (Population['Year'] == 2009), 'gini'] = 39.05
Population.loc[(Population['Country'] == "Thailand") & (Population['Year'] == 2011), 'gini'] = 37.53
Population.loc[(Population['Country'] == "Vietnam") & (Population['Year'] == 2010), 'gini'] = 38.79

# %%
print(Population.isnull().any())
print(Population.isnull().sum())
# Out:
# Country       False
# ISO3          False
# Year          False
# gini          False
# Population    False
# dtype: bool
# Country       0
# ISO3          0
# Year          0
# gini          0
# Population    0
# dtype: int64

# %% [markdown]
# ## 3.2.2.Doublons <a class="anchor" id="3.2.2"></a>

# %%
print(Population.duplicated().any())
print(Population.duplicated().sum())
# Out:
# True
# 185

# %%
Population[Population.duplicated()]
# Out:
#                   Country ISO3  Year   gini    Population
# 25                 Angola  AGO  2009  55.00    22514276.0
# 257               Armenia  ARM  2007  31.20     2932615.0
# 258               Armenia  ARM  2007  31.20     2932615.0
# 260               Armenia  ARM  2008  29.20     2907615.0
# 261               Armenia  ARM  2008  29.20     2907615.0
# 263               Armenia  ARM  2009  28.00     2888094.0
# 264               Armenia  ARM  2009  28.00     2888094.0
# 266               Armenia  ARM  2010  30.00     2877314.0
# 267               Armenia  ARM  2010  30.00     2877314.0
# 269               Armenia  ARM  2011  29.40     2876536.0
# 270               Armenia  ARM  2011  29.40     2876536.0
# 757               Austria  AUT  2011  27.98     8453501.0
# 1609              Bolivia  BOL  2008  50.82     9721457.0
# 1869               Brazil  BRA  2004  54.40   184006480.0
# 2297             Cambodia  KHM  2009  34.65    14093605.0
# 2299             Cambodia  KHM  2010  33.44    14312205.0
# 2301             Cambodia  KHM  2011  31.70    14541421.0
# 2651               Canada  CAN  2004  32.20    31815490.0
# 2672               Canada  CAN  2006  31.60    32536994.0
# 2996                Chile  CHL  2009  47.80    16886184.0
# 2999                Chile  CHL  2009  52.40    16886184.0
# 3548             Colombia  COL  2009  53.00    44750056.0
# 3560             Colombia  COL  2010  56.00    45222700.0
# 3566             Colombia  COL  2010  56.00    45222700.0
# 3853           Costa Rica  CRI  2010  49.20     4577371.0
# 3854           Costa Rica  CRI  2010  48.30     4577371.0
# 4152               Cyprus  CYP  2009  29.50     1098089.0
# 4357              Czechia  CZE  2006  25.30    10298609.0
# 4887              Denmark  DNK  2010  26.90     5554849.0
# 5143   Dominican Republic  DOM  2011  47.71     9813219.0
# 5305              Ecuador  ECU  2009  48.50    14774412.0
# 5430                Egypt  EGY  2009  31.10    81134792.0
# 5433                Egypt  EGY  2009  31.10    81134792.0
# 5570          El Salvador  SLV  2008  46.89     6131767.0
# 5576          El Salvador  SLV  2009  47.80     6157678.0
# 5579          El Salvador  SLV  2009  45.83     6157678.0
# 5585          El Salvador  SLV  2010  45.40     6183877.0
# 5783              Estonia  EST  2008  31.30     1340067.0
# 5823              Estonia  EST  2011  34.70     1327701.0
# 5976                 Fiji  FJI  2009  40.38      853636.0
# 6250              Finland  FIN  2004  26.60     5242175.0
# 6280              Finland  FIN  2006  26.80     5277490.0
# 6328              Finland  FIN  2009  25.90     5342266.0
# 6360              Finland  FIN  2011  31.47     5390036.0
# 6642               France  FRA  2006  28.07    61508924.0
# 6717               France  FRA  2011  33.78    63222232.0
# 7351              Germany  DEU  2008  49.40    81065752.0
# 7726               Greece  GRC  2008  33.00    11040312.0
# 7731               Greece  GRC  2009  33.10    10959268.0
# 7740               Greece  GRC  2009  33.10    10959268.0
# 7776               Greece  GRC  2011  33.50    10829074.0
# 8379              Hungary  HUN  2006  33.30    10055657.0
# 8415              Hungary  HUN  2008  25.20     9991867.0
# 8467              Hungary  HUN  2011  26.90     9895689.0
# 8581              Iceland  ISL  2004  26.10      291102.0
# 8647              Iceland  ISL  2008  31.36      310855.0
# 8649              Iceland  ISL  2008  30.33      310855.0
# 8650              Iceland  ISL  2008  37.54      310855.0
# 8654              Iceland  ISL  2008  38.70      310855.0
# 8667              Iceland  ISL  2009  26.60      316057.0
# 8976                India  IND  2010  29.00  1234281088.0
# 9333              Ireland  IRL  2004  32.30     4058131.0
# 9400              Ireland  IRL  2007  51.30     4324649.0
# 9411              Ireland  IRL  2008  31.92     4415871.0
# 9421              Ireland  IRL  2008  29.50     4415871.0
# 9422              Ireland  IRL  2008  53.80     4415871.0
# 9432              Ireland  IRL  2009  28.80     4494572.0
# 9443              Ireland  IRL  2009  31.20     4494572.0
# 9465              Ireland  IRL  2010  29.80     4554330.0
# 9478              Ireland  IRL  2011  29.80     4591115.0
# 9481              Ireland  IRL  2011  38.62     4591115.0
# 10011               Italy  ITA  2004  33.10    57948420.0
# 10060               Italy  ITA  2008  31.70    58922116.0
# 10074               Italy  ITA  2009  31.50    59105620.0
# 10379               Japan  JPN  2009  39.46   128555192.0
# 10380               Japan  JPN  2009  39.46   128555192.0
# 10381               Japan  JPN  2009  39.46   128555192.0
# 10382               Japan  JPN  2009  39.46   128555192.0
# 10383               Japan  JPN  2009  39.46   128555192.0
# 10384               Japan  JPN  2009  39.46   128555192.0
# 10385               Japan  JPN  2009  39.46   128555192.0
# 10386               Japan  JPN  2009  39.46   128555192.0
# 10387               Japan  JPN  2009  39.46   128555192.0
# 10388               Japan  JPN  2009  39.46   128555192.0
# 10389               Japan  JPN  2009  39.46   128555192.0
# 10390               Japan  JPN  2009  39.46   128555192.0
# 10481              Jordan  JOR  2009  32.57     6893258.0
# 10678  Korea, Republic of  KOR  2008  32.32    49182456.0
# 10922              Latvia  LVA  2008  37.50     2171248.0
# 10930              Latvia  LVA  2009  37.50     2144784.0
# 10966              Latvia  LVA  2011  35.10     2093606.0
# 11596          Luxembourg  LUX  2011  33.95      519312.0
# 11939           Mauritius  MUS  2007  35.65     1233890.0
# 11940           Mauritius  MUS  2007  35.65     1233890.0
# 12171              Mexico  MEX  2006  47.10   107560160.0
# 12397             Morocco  MAR  2007  41.00    31163670.0
# 12436             Namibia  NAM  2010  60.97     2118877.0
# 12437             Namibia  NAM  2010  60.97     2118877.0
# 12722         Netherlands  NLD  2011  32.49    16738191.0
# 12723         Netherlands  NLD  2011  30.41    16738191.0
# 12724         Netherlands  NLD  2011  30.71    16738191.0
# 12725         Netherlands  NLD  2011  37.52    16738191.0
# 12888         New Zealand  NZL  2008  33.00     4278156.0
# 12897         New Zealand  NZL  2011  32.30     4418674.0
# 12958           Nicaragua  NIC  2009  43.94     5745538.0
# 13003             Nigeria  NGA  2010  44.70   158503200.0
# 13259              Norway  NOR  2008  25.00     4771014.0
# 13273              Norway  NOR  2009  24.50     4826847.0
# 13295              Norway  NOR  2010  24.90     4885878.0
# 13309              Norway  NOR  2011  25.00     4948335.0
# 13310              Norway  NOR  2011  40.90     4948335.0
# 13406                Oman  OMN  2011  30.70     3251102.0
# 13527            Pakistan  PAK  2011  30.20   183340176.0
# 13528            Pakistan  PAK  2011  30.20   183340176.0
# 13529            Pakistan  PAK  2011  30.20   183340176.0
# 13857            Paraguay  PRY  2004  53.60     5730556.0
# 13897            Paraguay  PRY  2008  50.70     6081296.0
# 13919            Paraguay  PRY  2010  50.98     6248017.0
# 13928            Paraguay  PRY  2011  52.31     6333981.0
# 14108                Peru  PER  2006  50.33    28102054.0
# 14129                Peru  PER  2007  50.03    28333050.0
# 14137                Peru  PER  2008  42.10    28562320.0
# 14170                Peru  PER  2010  45.54    29027680.0
# 14179                Peru  PER  2011  44.66    29264314.0
# 14525              Poland  POL  2010  31.10    38329784.0
# 14537              Poland  POL  2010  33.22    38329784.0
# 14750            Portugal  PRT  2004  38.30    10470926.0
# 14797            Portugal  PRT  2008  35.80    10595312.0
# 15616           Singapore  SGP  2008  47.40     4775810.0
# 15739            Slovakia  SVK  2008  27.31     5399362.0
# 16005            Slovenia  SVN  2006  23.70     2002427.0
# 16043            Slovenia  SVN  2008  23.40     2023049.0
# 16520               Spain  ESP  2007  31.90    45429072.0
# 17253         Switzerland  CHE  2007  30.47     7536986.0
# 17255         Switzerland  CHE  2007  33.69     7536986.0
# 17257         Switzerland  CHE  2007  30.08     7536986.0
# 17258         Switzerland  CHE  2007  33.94     7536986.0
# 17272         Switzerland  CHE  2008  31.14     7622826.0
# 17298         Switzerland  CHE  2009  35.21     7713902.0
# 17337         Switzerland  CHE  2011  32.84     7906988.0
# 17339         Switzerland  CHE  2011  29.83     7906988.0
# 17340         Switzerland  CHE  2011  34.84     7906988.0
# 17343         Switzerland  CHE  2011  28.90     7906988.0
# 17344         Switzerland  CHE  2011  36.80     7906988.0
# 17696              Taiwan  TWN  2007  30.45    22927222.0
# 17804            Tanzania  TZA  2007  35.00    40681416.0
# 17895            Thailand  THA  2004  42.54    64995304.0
# 17897            Thailand  THA  2006  41.82    65812540.0
# 17899            Thailand  THA  2007  39.76    66182064.0
# 17902            Thailand  THA  2009  39.05    66866836.0
# 17903            Thailand  THA  2009  39.05    66866836.0
# 17906            Thailand  THA  2011  37.53    67518384.0
# 17907            Thailand  THA  2011  37.53    67518384.0
# 19321       United States  USA  2006  38.40   297758976.0
# 19329       United States  USA  2006  38.40   297758976.0
# 19363       United States  USA  2009  42.07   306307552.0
# 19628             Uruguay  URY  2009  43.30     3349676.0
# 19630             Uruguay  URY  2009  43.30     3349676.0
# 19642             Uruguay  URY  2010  43.80     3359273.0
# 19645             Uruguay  URY  2010  42.20     3359273.0
# 19654             Uruguay  URY  2011  40.20     3368926.0
# 19919             Vietnam  VNM  2004  37.00    83062824.0
# 19923             Vietnam  VNM  2004  37.00    83062824.0
# 19932             Vietnam  VNM  2004  33.20    83062824.0
# 19968             Vietnam  VNM  2010  38.79    87967656.0
# 19969             Vietnam  VNM  2010  38.79    87967656.0
# 19970             Vietnam  VNM  2010  38.79    87967656.0
# 19971             Vietnam  VNM  2010  38.79    87967656.0
# 19972             Vietnam  VNM  2010  38.79    87967656.0
# 19973             Vietnam  VNM  2010  38.79    87967656.0
# 19974             Vietnam  VNM  2010  38.79    87967656.0
# 19975             Vietnam  VNM  2010  38.79    87967656.0
# 19976             Vietnam  VNM  2010  38.79    87967656.0
# 19977             Vietnam  VNM  2010  38.79    87967656.0
# 19978             Vietnam  VNM  2010  38.79    87967656.0
# 19979             Vietnam  VNM  2010  38.79    87967656.0
# 19980             Vietnam  VNM  2010  38.79    87967656.0
# 19981             Vietnam  VNM  2010  38.79    87967656.0
# 19982             Vietnam  VNM  2010  38.79    87967656.0
# 19983             Vietnam  VNM  2010  38.79    87967656.0
# 19984             Vietnam  VNM  2010  38.79    87967656.0
# 19985             Vietnam  VNM  2010  38.79    87967656.0
# 19986             Vietnam  VNM  2010  38.79    87967656.0
# 20095  West Bank and Gaza  PSE  2011  42.52     4149654.0
# 20442              Israel  ISR  2009  42.71     7190037.0

# %% [markdown]
# ### J'ai detecté plusieurs lignes avec plusieurs valeurs d'indice de gini pour un meme pays, une meme année, selon plusieurs criteres, je décide garder que la premiere ligne de chaque pays.

# %%
Population.drop_duplicates(subset=['Country','ISO3','Year'],keep='first',inplace=True)

# %%
Population[Population.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, ISO3, Year, gini, Population]
# Index: []

# %%
print(Population.duplicated().any())
print(Population.duplicated().sum())
# Out:
# False
# 0

# %% [markdown]
# ## 3.2.3.Outliers, valeurs abberantes et atypiques <a class="anchor" id="3.2.3"></a>

# %%
Population.head()
# Out:
#          Country ISO3  Year   gini  Population
# 0    Afghanistan  AFG  2008  29.00  27722282.0
# 6        Albania  ALB  2008  29.98   3002683.0
# 21        Angola  AGO  2009  55.00  22514276.0
# 154    Argentina  ARG  2004  48.45  38491968.0
# 164    Argentina  ARG  2006  46.61  39289876.0

# %%
Population.loc[(Population['gini'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Country, ISO3, Year, gini, Population]
# Index: []

# %%
len(Population['Country'].unique())
# Out:
# 173

# %%
# Je regarde les extremes pour la colonne gini
Population.groupby('ISO3').mean().sort_values('gini').tail()
# Out:
#         Year    gini  Population
# ISO3
# CAF   2008.0  56.240   4273368.0
# BRN   2011.0  56.400    393687.0
# CIV   2008.0  56.560  19605568.0
# NAM   2007.0  60.485   2013307.0
# ZAF   2009.5  68.870  50869302.0

# %%
# Je regarde les extremes pour la colonne population
Population.groupby('ISO3').mean().sort_values('Population').tail()
# Out:
#               Year        gini     Population
# ISO3
# BRA   2007.5000000  53.2533333  1.9095594e+08
# IDN   2007.8571429  35.7142857  2.3514552e+08
# USA   2007.8571429  41.0128571  3.0301588e+08
# IND   2008.3333333  44.8333333  1.2047309e+09
# CHN   2008.5000000  48.5000000  1.3574083e+09

# %% [markdown]
# ### RAS

# %% [markdown]
# ## 3.2.4.Jointure des tables Population et data_projet7 <a class="anchor" id="3.2.4"></a>

# %%
data_projet7 = pd.merge(data_projet7,Population, on= ['ISO3'], how= 'left')
data_projet7 = data_projet7.drop(columns =['Country_y','Year_y'])
data_projet7 = data_projet7.rename(columns ={'Country_x':'Country'})
data_projet7 = data_projet7.rename(columns ={'Year_x':'Year'})

data_projet7.head(3)
# Out:
#   ISO3  Year  quantile  nb_quantiles      income  gdpppp  Country   gini  \
# 0  ALB  2008         1           100   728.89795  7297.0  Albania  29.98
# 1  ALB  2008         2           100   916.66235  7297.0  Albania  29.98
# 2  ALB  2008         3           100  1010.91600  7297.0  Albania  29.98
#
#    Population
# 0   3002683.0
# 1   3002683.0
# 2   3002683.0

# %%
len(data_projet7['Country'].unique())
# Out:
# 116

# %%
data_projet7.shape
# Out:
# (54800, 9)

# %%
data_projet7.dtypes
# Out:
# ISO3             object
# Year              int64
# quantile          int64
# nb_quantiles      int64
# income          float64
# gdpppp          float64
# Country          object
# gini            float64
# Population      float64
# dtype: object

# %%
print(data_projet7.isnull().any())
print(data_projet7.isnull().sum())
# Out:
# ISO3            False
# Year            False
# quantile        False
# nb_quantiles    False
# income          False
# gdpppp          False
# Country         False
# gini             True
# Population       True
# dtype: bool
# ISO3              0
# Year              0
# quantile          0
# nb_quantiles      0
# income            0
# gdpppp            0
# Country           0
# gini            100
# Population      100
# dtype: int64

# %%
data_projet7[data_projet7['gini'].isnull()]
# Out:
#       ISO3  Year  quantile  nb_quantiles       income     gdpppp  \
# 54693  COD  2008         1           100    29.364283  303.19305
# 54694  COD  2008         2           100    40.948640  303.19305
# 54695  COD  2008         3           100    47.906730  303.19305
# 54696  COD  2008         4           100    53.693500  303.19305
# 54697  COD  2008         5           100    58.434020  303.19305
# 54698  COD  2008         6           100    63.338570  303.19305
# 54699  COD  2008         7           100    67.120610  303.19305
# 54700  COD  2008         8           100    70.029170  303.19305
# 54701  COD  2008         9           100    73.610120  303.19305
# 54702  COD  2008        10           100    76.695500  303.19305
# 54703  COD  2008        11           100    79.145424  303.19305
# 54704  COD  2008        12           100    82.521070  303.19305
# 54705  COD  2008        13           100    85.565260  303.19305
# 54706  COD  2008        14           100    88.417980  303.19305
# 54707  COD  2008        15           100    90.938110  303.19305
# 54708  COD  2008        16           100    93.222730  303.19305
# 54709  COD  2008        17           100    95.716870  303.19305
# 54710  COD  2008        18           100    98.352394  303.19305
# 54711  COD  2008        19           100   100.667070  303.19305
# 54712  COD  2008        20           100   102.757690  303.19305
# 54713  COD  2008        21           100   105.523710  303.19305
# 54714  COD  2008        22           100   107.885080  303.19305
# 54715  COD  2008        23           100   110.485220  303.19305
# 54716  COD  2008        24           100   112.590080  303.19305
# 54717  COD  2008        25           100   114.652890  303.19305
# 54718  COD  2008        26           100   116.524284  303.19305
# 54719  COD  2008        27           100   119.302320  303.19305
# 54720  COD  2008        28           100   122.528060  303.19305
# 54721  COD  2008        29           100   125.392380  303.19305
# 54722  COD  2008        30           100   127.919600  303.19305
# 54723  COD  2008        31           100   130.130340  303.19305
# 54724  COD  2008        32           100   132.417760  303.19305
# 54725  COD  2008        33           100   135.218250  303.19305
# 54726  COD  2008        34           100   138.000370  303.19305
# 54727  COD  2008        35           100   141.166120  303.19305
# 54728  COD  2008        36           100   143.825670  303.19305
# 54729  COD  2008        37           100   146.201190  303.19305
# 54730  COD  2008        38           100   148.586520  303.19305
# 54731  COD  2008        39           100   151.674440  303.19305
# 54732  COD  2008        40           100   154.441420  303.19305
# 54733  COD  2008        41           100   156.958940  303.19305
# 54734  COD  2008        42           100   159.238100  303.19305
# 54735  COD  2008        43           100   161.314450  303.19305
# 54736  COD  2008        44           100   164.056440  303.19305
# 54737  COD  2008        45           100   167.363040  303.19305
# 54738  COD  2008        46           100   170.638820  303.19305
# 54739  COD  2008        47           100   174.353850  303.19305
# 54740  COD  2008        48           100   177.756470  303.19305
# 54741  COD  2008        49           100   181.073880  303.19305
# 54742  COD  2008        50           100   184.929720  303.19305
# 54743  COD  2008        51           100   188.918400  303.19305
# 54744  COD  2008        52           100   192.284480  303.19305
# 54745  COD  2008        53           100   196.641400  303.19305
# 54746  COD  2008        54           100   200.086520  303.19305
# 54747  COD  2008        55           100   203.676450  303.19305
# 54748  COD  2008        56           100   207.022100  303.19305
# 54749  COD  2008        57           100   211.096120  303.19305
# 54750  COD  2008        58           100   215.045270  303.19305
# 54751  COD  2008        59           100   219.538760  303.19305
# 54752  COD  2008        60           100   224.577730  303.19305
# 54753  COD  2008        61           100   229.454210  303.19305
# 54754  COD  2008        62           100   234.034260  303.19305
# 54755  COD  2008        63           100   238.960000  303.19305
# 54756  COD  2008        64           100   243.530530  303.19305
# 54757  COD  2008        65           100   248.246190  303.19305
# 54758  COD  2008        66           100   255.272690  303.19305
# 54759  COD  2008        67           100   261.030730  303.19305
# 54760  COD  2008        68           100   267.245730  303.19305
# 54761  COD  2008        69           100   273.740540  303.19305
# 54762  COD  2008        70           100   281.360080  303.19305
# 54763  COD  2008        71           100   288.982670  303.19305
# 54764  COD  2008        72           100   295.195220  303.19305
# 54765  COD  2008        73           100   303.546170  303.19305
# 54766  COD  2008        74           100   311.324130  303.19305
# 54767  COD  2008        75           100   318.717220  303.19305
# 54768  COD  2008        76           100   325.341580  303.19305
# 54769  COD  2008        77           100   334.038820  303.19305
# 54770  COD  2008        78           100   343.482450  303.19305
# 54771  COD  2008        79           100   355.646200  303.19305
# 54772  COD  2008        80           100   364.816040  303.19305
# 54773  COD  2008        81           100   375.831270  303.19305
# 54774  COD  2008        82           100   388.961100  303.19305
# 54775  COD  2008        83           100   403.030460  303.19305
# 54776  COD  2008        84           100   416.481900  303.19305
# 54777  COD  2008        85           100   429.232480  303.19305
# 54778  COD  2008        86           100   445.163820  303.19305
# 54779  COD  2008        87           100   462.341900  303.19305
# 54780  COD  2008        88           100   483.641900  303.19305
# 54781  COD  2008        89           100   507.318800  303.19305
# 54782  COD  2008        90           100   534.014500  303.19305
# 54783  COD  2008        91           100   564.684600  303.19305
# 54784  COD  2008        92           100   600.175840  303.19305
# 54785  COD  2008        93           100   639.259300  303.19305
# 54786  COD  2008        94           100   684.707100  303.19305
# 54787  COD  2008        95           100   743.372000  303.19305
# 54788  COD  2008        96           100   810.623300  303.19305
# 54789  COD  2008        97           100   911.783400  303.19305
# 54790  COD  2008        98           100  1057.807400  303.19305
# 54791  COD  2008        99           100  1286.602900  303.19305
# 54792  COD  2008       100           100  2243.122600  303.19305
#
#                                 Country  gini  Population
# 54693  Congo Democratic Republic of the   NaN         NaN
# 54694  Congo Democratic Republic of the   NaN         NaN
# 54695  Congo Democratic Republic of the   NaN         NaN
# 54696  Congo Democratic Republic of the   NaN         NaN
# 54697  Congo Democratic Republic of the   NaN         NaN
# 54698  Congo Democratic Republic of the   NaN         NaN
# 54699  Congo Democratic Republic of the   NaN         NaN
# 54700  Congo Democratic Republic of the   NaN         NaN
# 54701  Congo Democratic Republic of the   NaN         NaN
# 54702  Congo Democratic Republic of the   NaN         NaN
# 54703  Congo Democratic Republic of the   NaN         NaN
# 54704  Congo Democratic Republic of the   NaN         NaN
# 54705  Congo Democratic Republic of the   NaN         NaN
# 54706  Congo Democratic Republic of the   NaN         NaN
# 54707  Congo Democratic Republic of the   NaN         NaN
# 54708  Congo Democratic Republic of the   NaN         NaN
# 54709  Congo Democratic Republic of the   NaN         NaN
# 54710  Congo Democratic Republic of the   NaN         NaN
# 54711  Congo Democratic Republic of the   NaN         NaN
# 54712  Congo Democratic Republic of the   NaN         NaN
# 54713  Congo Democratic Republic of the   NaN         NaN
# 54714  Congo Democratic Republic of the   NaN         NaN
# 54715  Congo Democratic Republic of the   NaN         NaN
# 54716  Congo Democratic Republic of the   NaN         NaN
# 54717  Congo Democratic Republic of the   NaN         NaN
# 54718  Congo Democratic Republic of the   NaN         NaN
# 54719  Congo Democratic Republic of the   NaN         NaN
# 54720  Congo Democratic Republic of the   NaN         NaN
# 54721  Congo Democratic Republic of the   NaN         NaN
# 54722  Congo Democratic Republic of the   NaN         NaN
# 54723  Congo Democratic Republic of the   NaN         NaN
# 54724  Congo Democratic Republic of the   NaN         NaN
# 54725  Congo Democratic Republic of the   NaN         NaN
# 54726  Congo Democratic Republic of the   NaN         NaN
# 54727  Congo Democratic Republic of the   NaN         NaN
# 54728  Congo Democratic Republic of the   NaN         NaN
# 54729  Congo Democratic Republic of the   NaN         NaN
# 54730  Congo Democratic Republic of the   NaN         NaN
# 54731  Congo Democratic Republic of the   NaN         NaN
# 54732  Congo Democratic Republic of the   NaN         NaN
# 54733  Congo Democratic Republic of the   NaN         NaN
# 54734  Congo Democratic Republic of the   NaN         NaN
# 54735  Congo Democratic Republic of the   NaN         NaN
# 54736  Congo Democratic Republic of the   NaN         NaN
# 54737  Congo Democratic Republic of the   NaN         NaN
# 54738  Congo Democratic Republic of the   NaN         NaN
# 54739  Congo Democratic Republic of the   NaN         NaN
# 54740  Congo Democratic Republic of the   NaN         NaN
# 54741  Congo Democratic Republic of the   NaN         NaN
# 54742  Congo Democratic Republic of the   NaN         NaN
# 54743  Congo Democratic Republic of the   NaN         NaN
# 54744  Congo Democratic Republic of the   NaN         NaN
# 54745  Congo Democratic Republic of the   NaN         NaN
# 54746  Congo Democratic Republic of the   NaN         NaN
# 54747  Congo Democratic Republic of the   NaN         NaN
# 54748  Congo Democratic Republic of the   NaN         NaN
# 54749  Congo Democratic Republic of the   NaN         NaN
# 54750  Congo Democratic Republic of the   NaN         NaN
# 54751  Congo Democratic Republic of the   NaN         NaN
# 54752  Congo Democratic Republic of the   NaN         NaN
# 54753  Congo Democratic Republic of the   NaN         NaN
# 54754  Congo Democratic Republic of the   NaN         NaN
# 54755  Congo Democratic Republic of the   NaN         NaN
# 54756  Congo Democratic Republic of the   NaN         NaN
# 54757  Congo Democratic Republic of the   NaN         NaN
# 54758  Congo Democratic Republic of the   NaN         NaN
# 54759  Congo Democratic Republic of the   NaN         NaN
# 54760  Congo Democratic Republic of the   NaN         NaN
# 54761  Congo Democratic Republic of the   NaN         NaN
# 54762  Congo Democratic Republic of the   NaN         NaN
# 54763  Congo Democratic Republic of the   NaN         NaN
# 54764  Congo Democratic Republic of the   NaN         NaN
# 54765  Congo Democratic Republic of the   NaN         NaN
# 54766  Congo Democratic Republic of the   NaN         NaN
# 54767  Congo Democratic Republic of the   NaN         NaN
# 54768  Congo Democratic Republic of the   NaN         NaN
# 54769  Congo Democratic Republic of the   NaN         NaN
# 54770  Congo Democratic Republic of the   NaN         NaN
# 54771  Congo Democratic Republic of the   NaN         NaN
# 54772  Congo Democratic Republic of the   NaN         NaN
# 54773  Congo Democratic Republic of the   NaN         NaN
# 54774  Congo Democratic Republic of the   NaN         NaN
# 54775  Congo Democratic Republic of the   NaN         NaN
# 54776  Congo Democratic Republic of the   NaN         NaN
# 54777  Congo Democratic Republic of the   NaN         NaN
# 54778  Congo Democratic Republic of the   NaN         NaN
# 54779  Congo Democratic Republic of the   NaN         NaN
# 54780  Congo Democratic Republic of the   NaN         NaN
# 54781  Congo Democratic Republic of the   NaN         NaN
# 54782  Congo Democratic Republic of the   NaN         NaN
# 54783  Congo Democratic Republic of the   NaN         NaN
# 54784  Congo Democratic Republic of the   NaN         NaN
# 54785  Congo Democratic Republic of the   NaN         NaN
# 54786  Congo Democratic Republic of the   NaN         NaN
# 54787  Congo Democratic Republic of the   NaN         NaN
# 54788  Congo Democratic Republic of the   NaN         NaN
# 54789  Congo Democratic Republic of the   NaN         NaN
# 54790  Congo Democratic Republic of the   NaN         NaN
# 54791  Congo Democratic Republic of the   NaN         NaN
# 54792  Congo Democratic Republic of the   NaN         NaN

# %% [markdown]
# ### Il manque l'indice de gini et la population pour le Congo > Imputation

# %%
# Je remplace les NaN de la colonne gini pour leur affecter une nouvelle valeur
data_projet7['gini'] = data_projet7['gini'].fillna(0)
data_projet7['Population'] = data_projet7['Population'].fillna(0)

# Imputation
data_projet7.loc[(data_projet7['ISO3'] == "COD") & (data_projet7['Year'] == '2008'), 'Population'] = 4011486
data_projet7.loc[(data_projet7['ISO3'] == "COD") & (data_projet7['Year'] == 2008), 'gini'] = 42.1

# %%
print(data_projet7.isnull().any())
# Out:
# ISO3            False
# Year            False
# quantile        False
# nb_quantiles    False
# income          False
# gdpppp          False
# Country         False
# gini            False
# Population      False
# dtype: bool

# %%
print(data_projet7.duplicated().any())
print(data_projet7.duplicated().sum())
# Out:
# False
# 0

# %%
# Je vérifie si certaine variables ne présentent pas de données
data_projet7_uniqlast = data_projet7.groupby(by='ISO3').nunique()
data_projet7_uniqlast.head()
# Out:
#       Year  quantile  nb_quantiles  income  gdpppp  Country  gini  Population
# ISO3
# ALB      1       100             1     100       1        1     1           1
# ARG      1       100             1     100       1        1     7           7
# ARM      1       100             1     100       1        1     7           7
# AUT      1       100             1     100       1        1     7           7
# AZE      1       100             1     100       1        1     1           1

# %%
# Vérification pour la variable gini
data_projet7_uniqlast.loc[data_projet7_uniqlast['gini'] < 1]
# Out:
# Empty DataFrame
# Columns: [Year, quantile, nb_quantiles, income, gdpppp, Country, gini, Population]
# Index: []

# %%
# Je vérifie si certaine variables ne présentent pas de données
data_projet7_uniqlast2 = data_projet7.groupby(by='ISO3').nunique()
data_projet7_uniqlast2.loc[data_projet7_uniqlast2['gini'] < 1]
# Out:
# Empty DataFrame
# Columns: [Year, quantile, nb_quantiles, income, gdpppp, Country, gini, Population]
# Index: []

# %%
# Vérification pour la variable Population
data_projet7_uniqlast.loc[data_projet7_uniqlast['Population'] < 1]
# Out:
# Empty DataFrame
# Columns: [Year, quantile, nb_quantiles, income, gdpppp, Country, gini, Population]
# Index: []

# %%
# Vérification pour la variable income
data_projet7_uniqlast.loc[data_projet7_uniqlast['income'] < 1]
# Out:
# Empty DataFrame
# Columns: [Year, quantile, nb_quantiles, income, gdpppp, Country, gini, Population]
# Index: []

# %%
# Vérification pour la variable gdpppp
data_projet7_uniqlast.loc[data_projet7_uniqlast['gdpppp'] < 1]
# Out:
# Empty DataFrame
# Columns: [Year, quantile, nb_quantiles, income, gdpppp, Country, gini, Population]
# Index: []

# %%
data_projet7.head()
# Out:
#   ISO3  Year  quantile  nb_quantiles      income  gdpppp  Country   gini  \
# 0  ALB  2008         1           100   728.89795  7297.0  Albania  29.98
# 1  ALB  2008         2           100   916.66235  7297.0  Albania  29.98
# 2  ALB  2008         3           100  1010.91600  7297.0  Albania  29.98
# 3  ALB  2008         4           100  1086.90780  7297.0  Albania  29.98
# 4  ALB  2008         5           100  1132.69970  7297.0  Albania  29.98
#
#    Population
# 0   3002683.0
# 1   3002683.0
# 2   3002683.0
# 3   3002683.0
# 4   3002683.0

# %%
# J'exporte ma table en CSV pour la suite
#data_projet7.to_csv("C:/Users/33643/Desktop/P7/CSV2/data_projet7_clean.csv", index=False,encoding='utf-8-sig')

# %%
len(data_projet7['Country'].unique())
# Out:
# 116

# %% [markdown]
# ## 3.3.Proportion de la population etudiée vs 2008 <a class="anchor" id="3.3"></a>

# %%
Pop_tot_2008 = 6757000000
print('La population totale en 2008 est de', Pop_tot_2008, 'habitants')
# Out:
# La population totale en 2008 est de 6757000000 habitants

# %% [markdown]
# *source : https://donnees.banquemondiale.org/indicator/SP.POP.TOTL*

# %%
data_projet7_grouped = data_projet7.groupby('Country').mean()
data_projet7_pop = data_projet7_grouped['Population'].sum()
data_projet7_pop_ratio = (data_projet7_pop / Pop_tot_2008)*100

print("La population totale couverte par l'étude est de", data_projet7_pop, 'habitants')
print("Ce qui représente", data_projet7_pop_ratio, '% de la population mondiale')
# Out:
# La population totale couverte par l'étude est de 6171461397.004762 habitants
# Ce qui représente 91.33434063940746 % de la population mondiale

# %% [markdown]
# ### <font color='red'> La population couverte par l'étude est de 91,3% (par rapport à la population totale de 2008) </font>
